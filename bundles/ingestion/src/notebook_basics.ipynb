# %%
# comment notation because this is python
print("Hello World")
# Out:
# Hello World

# %%
# %sql
-- new cell! default shortcut is shift + Enter
-- this one is SQL, thanks to the magic command shows in row 1
-- cannot change mid-cell
SELECT 'hello world from sql'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>'hello world from sql'</th></tr></thead><tbody><tr><td>hello world from sql</td></tr></tbody></table></div>

# %% [markdown]
# ## title 1
# ### title 2
# #### title 3
# ##### title 4

# %%
# runs another notebook (as Includes, thus the folder name)
# this is CRAZY powerful, because it means you can store functions in a notebook and then call them from anywhere
# is there a way to call a specific function from the referenced file instead of the whole thing? Or maybe it's just function declarations and we allow them all to be imported because we're lazy
# %run ./Includes/Setup

# %%
# prove our Includes run worked
print(full_name)
# Out:
# Ben Pack

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
# use dbutils to read directory contents and display
files = dbutils.fs.ls("/Workspace/Users/benjamin.pack@zealitconsultants.ai/")
display(files)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
